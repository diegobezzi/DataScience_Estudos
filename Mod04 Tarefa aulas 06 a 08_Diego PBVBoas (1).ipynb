# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

r = requests.get(url)

data_json = r.json()

cond_pvl = pd.DataFrame(data_json['items'])
cond_pvl[cond_pvl['uf'] == 'RJ']
# Out:
#       id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 48         6670        Município  Duque de Caxias   3301702  RJ
# 69         4977        Município       Petrópolis   3303906  RJ
# 157        5713        Município    Volta Redonda   3306305  RJ
# 210       13584        Município   Rio de Janeiro   3304557  RJ
# 346       65965        Município      Barra Mansa   3300407  RJ
# ...         ...              ...              ...       ...  ..
# 4568      24808        Município   Rio de Janeiro   3304557  RJ
# 4665      13629           Estado   Rio de Janeiro        33  RJ
# 4748      13638        Município      São Gonçalo   3304904  RJ
# 4783      11340        Município        Nilópolis   3303203  RJ
# 4985      13443        Município      Nova Iguaçu   3303500  RJ
#
#                    num_pvl                          status  \
# 48                    None                        Deferido
# 69                    None  Arquivado por decurso de prazo
# ...

# %%
# 2) Seu código aqui

status = pd.DataFrame(data_json['items'])

status = status['status'].value_counts()
status.head(3)
# Out:
# Deferido             2582
# Deferido (PVL-IF)    1198
# Arquivado             386
# Name: status, dtype: int64

# %%
# 3) Seu código aqui

df = pd.DataFrame(data_json['items'])

data = df['data_status'].astype(str)

df['ano_status'] = df['data_status'].str.slice(6, 10)
df['ano_status']
# Out:
# 0       2022
# 1       2023
# 2       2023
# 3       2023
# 4       2022
#         ...
# 4995    2014
# 4996    2014
# 4997    2002
# 4998    2007
# 4999    2014
# Name: ano_status, Length: 5000, dtype: object

# %%
# 4) Seu código aqui

df['ano_status'].value_counts()
# Out:
# 2019    442
# 2008    408
# 2022    345
# 2023    318
# 2021    317
# 2018    274
# 2010    272
# 2020    269
# 2007    254
# 2014    234
# 2012    222
# 2006    212
# 2011    207
# 2013    205
# 2017    204
# 2004    168
# 2009    158
# 2015    129
# 2016    128
# 2002    113
# 2003     85
# 2005     36
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
df = pd.DataFrame(data_json['items'])

def retorna_uf (uf):
    df1 = df
    df_uf = (df1[df1['uf'] == uf])
      
    return df_uf

retorna_uf('TO')
# Out:
#       id_pleito tipo_interessado                interessado  cod_ibge  uf  \
# 136       13242           Estado                  Tocantins        17  TO
# 161       19216           Estado                  Tocantins        17  TO
# 458       19696        Município             Porto Nacional   1718204  TO
# 630       38882        Município       Colinas do Tocantins   1705508  TO
# 791       64817        Município             Porto Nacional   1718204  TO
# 809       48410        Município         Brejinho de Nazaré   1703701  TO
# 902       29248        Município       Paraíso do Tocantins   1716109  TO
# 989       13239           Estado                  Tocantins        17  TO
# 1089      26716           Estado                  Tocantins        17  TO
# 1153      49551        Município                Sandolândia   1718840  TO
# 1165      64374        Município                   Arapoema   1702307  TO
# 1171      61127        Município        Cariri do Tocantins   1703867  TO
# ...

# %%
# 2) Seu código aqui
df = pd.DataFrame(data_json['items'])

mg = (df['uf'] == 'MG')& (df['status'] == 'Arquivado por decurso de prazo')
df[mg]['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    56
# Name: status, dtype: int64

# %%
# 3) Seu código aqui

ba = (df['uf'] == 'BA')& (df['status'] == 'Deferido')
df[ba]['interessado'].value_counts()
# Out:
# Bahia                     18
# Luís Eduardo Magalhães     4
# Bom Jesus da Lapa          4
# Teixeira de Freitas        4
# Barreiras                  4
#                           ..
# Oliveira dos Brejinhos     1
# Ibicuí                     1
# Sapeaçu                    1
# Jiquiriçá                  1
# Jaguarari                  1
# Name: interessado, Length: 86, dtype: int64

# %%
# 4) Seu código aqui

ba = (df['uf'] == 'BA')& (df['tipo_interessado'] == 'Estado')
df[ba]
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 30        18633           Estado       Bahia        29  BA
# 98        18531           Estado       Bahia        29  BA
# 101       19016           Estado       Bahia        29  BA
# 129       18589           Estado       Bahia        29  BA
# 132       18595           Estado       Bahia        29  BA
# 152       18591           Estado       Bahia        29  BA
# 415       18559           Estado       Bahia        29  BA
# 416       18567           Estado       Bahia        29  BA
# 417       18571           Estado       Bahia        29  BA
# 542       45396           Estado       Bahia        29  BA
# 1235      18515           Estado       Bahia        29  BA
# 1532      10198           Estado       Bahia        29  BA
# 1825      43670           Estado       Bahia        29  BA
# 2163       8342           Estado       Bahia        29  BA
# 2417      18503           Estado       Bahia        29  BA
# ...

# %%
df[ba].to_csv('C:/Users/User/Desktop/Anaconda Projects/Modulo 4/tarefa_modulo-4.csv')
